# %%
#SONOLA MOYOSOLUWALORUN
#ID: 1479301970c1f000
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('FoodBalanceSheetAfrica.csv')
df.to_csv('FoodBalanceSheetAfrica.csv', index=False)

#'utf-8' codec can't decode byte 0xf4 in position 87447: invalid continuation byte
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6508/3142296140.py in <module>
# ----> 1 df = pd.read_csv('FoodBalanceSheetAfrica.csv')
#       2 df.to_csv('FoodBalanceSheetAfrica.csv', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
