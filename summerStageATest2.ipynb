# %% [markdown]
# <a href="https://colab.research.google.com/github/SonolaMoyo/HamoyeSummer2022/blob/main/summerStageATest2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import plotting library
import matplotlib.pyplot as plt

#import pandas library
import pandas as pd

#import seaborn for plotting
import seaborn as sns

plt.figure(figsize=(7,4))
plt.xticks(rotation=90)

fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU',
'MWDTH', 'MWHTH', 'TON'],
'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})

sns.barplot(data=fuel_unit, x="unit", y="count")
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %% [markdown]
# Because of the extreme range of the values for the fuel unit, we can plot the
# barchart by taking the logarithm of the y-axis as follows:

# %%
g = sns.barplot(data=fuel_unit, x="unit", y="count")
g.set_yscale('log')
g.set_ylim(1, 12000)
plt.xlabel("Fuel Unit 2")
# Out:
# Text(0.5, 0, 'Fuel Unit 2')

# %%
url='https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'
fuel_data = pd.read_csv(url)

#Select a sample of the dataset
sample_df = fuel_data.sample(n=50, random_state=4)

#regression plot
sns.regplot(x=sample_df["utility_id_ferc1"], y=sample_df["fuel_cost_per_mmbtu"], fit_reg=False)

# %%
fuel_data.head(100)
# Out:
#                   record_id  utility_id_ferc1  report_year  \
# 0     f1_fuel_1994_12_1_0_7                 1         1994
# 1    f1_fuel_1994_12_1_0_10                 1         1994
# 2     f1_fuel_1994_12_2_0_1                 2         1994
# 3     f1_fuel_1994_12_2_0_7                 2         1994
# 4    f1_fuel_1994_12_2_0_10                 2         1994
# ..                      ...               ...          ...
# 95   f1_fuel_1994_12_17_0_8                17         1994
# 96  f1_fuel_1994_12_17_0_10                17         1994
# 97  f1_fuel_1994_12_17_0_14                17         1994
# 98   f1_fuel_1994_12_17_1_6                17         1994
# 99  f1_fuel_1994_12_17_1_11                17         1994
#
#         plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0               rockport                coal       ton        5377489.0
# 1   rockport total plant                coal       ton       10486945.0
# ...

# %%
#box plot
sns.boxplot(x="fuel_type_code_pudl", y="utility_id_ferc1", palette=["m","g"], data=fuel_data)

# %%
#Kernel Density Estimate(KDE) plots
sns.kdeplot(sample_df['fuel_cost_per_unit_burned'], shade=True, color='b')
